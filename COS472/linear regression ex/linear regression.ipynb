# %%
# Let’s generate some linear-looking data

import numpy as np

X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# %%
# Randomly generated linear dataset
import matplotlib.pyplot as plt
plt.scatter(X, y)
plt.show()

# %%
# install the sklearn library by conda or pip command
# conda install scikit-learn
# pip install scikit-learn

# Performing linear regression using Scikit-Learn is quite simple
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html

from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
# fit linear model
lin_reg.fit(X, y)
# Out:
# LinearRegression()

# %%
# Return the coefficient of determination of the prediction: R^2
# The best possible score is 1.0 and it can be negative (because the model can be arbitrarily worse)

lin_reg.score(X, y)
# Out:
# 0.8057942369338903

# %%
# Estimated coefficients for the linear regression problem: W
w = lin_reg.coef_

# %%
# Independent(bias) term in the linear model: b
b =lin_reg.intercept_

# %%
w,b
# Out:
# (array([[3.04544928]]), array([3.89906709]))

# %%
# Model Evaluation 
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, y_pred) 
rmse = np.sqrt(mse)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       1 # Model Evaluation
#       2 from sklearn.metrics import mean_squared_error
# ----> 4 mse = mean_squared_error(y_test, y_pred)
#       5 rmse = np.sqrt(mse)
#
# NameError: name 'y_test' is not defined

# %%
# plot y = w*x + b

mn=np.min(X)
mx=np.max(X)
x1=np.linspace(mn,mx,500)
y1=(w*x1+b).squeeze()
plt.scatter(X, y)
plt.plot(x1,y1,'-r')
plt.show()
